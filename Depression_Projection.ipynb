# %% [markdown]
# This is a guide on how to project into Neil's depression network.
#
# This guide assumes you know how to generate features using the MATLAB pipeline.

# %% [markdown]
# If you're reading this, you're in the right place, since you need to be using a specific version of the MATLAB pipeline in order to make features that are compatible with depression network projection.

# %% [markdown]
# Ideally, you are accessing this through GitHub, where you've cloned this repository to your local machine and have swithced to this branch instead of downloading a version of the code outside of GitHub.
#
# If you do not have this and don't know how to do this, talk to Noah.

# %% [markdown]
# In order to projet into the depression network, you have to generate the features in the right way. There are two things that go into this. First, you have to have the right channel group names. This means the names of your grouped areas have to exactly match the names of the groups in the netowrk htat was originally generated by Neil. Teh group names that you must have are ___ . You cannoot include groups that are not in this list and you also cannot NOT have groups that are in this list, yuou have to have all of the groups in the list, not one more or less.

# %% [markdown]
# The secon thing you have to do in terms of preprocessing is to have all of the same arguments you put into the pipeline be the same. Sampling freq, window size, feature version, they all have to be the same. If you get these wrong, project, and get a result, the reuslts are not interpretable, it's just a number with no discernable meaning.
